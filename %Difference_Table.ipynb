# %% [markdown]
# <a href="https://colab.research.google.com/github/RajeshworM/Yield_Modelling_Automation/blob/main/%25Difference_Table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color ='Blue'> <font size ='6'> **Graphical Representaion for Heatmap for % Error**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Recreate the dataset from the table
data = {
    "States": [
        "Andhra Pradesh (incl. Telangana)", "Assam", "Bihar", "Chhattisgarh", "Gujarat", "Haryana",
        "Jharkhand", "Karnataka", "Madhya Pradesh", "Maharashtra", "Orissa", "Punjab", "Rajasthan",
        "Tamilnadu", "Uttar Pradesh", "Uttarakhand", "West Bengal"
    ],
    "Rice Kharif": [2.5, 3.1, 4.9, 7.9, 9.1, 2.2, 6, 1.5, 7.7, 3.3, 7.4, 1.3, np.nan, 6.1, 3, 4, 1.4],
    "Bajra": [np.nan, np.nan, np.nan, np.nan, 6.9, 5.8, np.nan, 5.8, 4.5, 7.3, np.nan, np.nan, 15.1, np.nan, 3.1, np.nan, np.nan],
    "Jowar Kharif": [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 4.8, 7.7, 2.6, np.nan, np.nan, 8.8, 5.5, 6.8, np.nan, np.nan],
    "Maize Kharif": [6, np.nan, 11.3, 8, 10.1, np.nan, 4, 5.1, 9.8, 10.4, np.nan, 4.9, 8.4, 12.2, 5.4, np.nan, np.nan],
    "Arhar": [4.7, np.nan, np.nan, np.nan, 6.6, np.nan, 6, 8.9, 3.6, 7.1, 5.7, np.nan, np.nan, np.nan, 7.8, np.nan, np.nan],
    "Moong Kharif": [np.nan, np.nan, np.nan, np.nan, 14.7, np.nan, np.nan, 14.3, 10.4, 3.3, np.nan, np.nan, 16.5, np.nan, np.nan, np.nan, np.nan],
    "Urad Kharif": [np.nan, np.nan, np.nan, np.nan, 9.4, np.nan, np.nan, 11.4, 8, 6.4, 4, np.nan, 7.7, np.nan, 14.7, np.nan, np.nan],
    "Soybean": [np.nan, np.nan, np.nan, np.nan, 13, np.nan, np.nan, 11, 4.8, 6.2, np.nan, np.nan, 13.6, np.nan, np.nan, np.nan, np.nan],
    "GN Kharif": [6.6, np.nan, np.nan, np.nan, 16.9, np.nan, 4.7, 4.9, 5.8, 3.2, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan],
    "Castor Seed": [np.nan, np.nan, np.nan, np.nan, 1.5, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 9.1, np.nan, np.nan, np.nan, np.nan],
    "Jute": [np.nan, 4, 6, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 2],
    "Cotton": [4, np.nan, np.nan, np.nan, 10.9, 6.2, np.nan, 7.2, 5.4, 9.3, 1.8, 6.9, 12.1, 11.2, np.nan, np.nan, np.nan],
    "Sugarcane": [1.4, np.nan, 2.4, np.nan, 1.1, 1.7, np.nan, 1.8, 4.4, 4, np.nan, 2.8, np.nan, 1, 1.6, np.nan, np.nan]
}

df = pd.DataFrame(data)
df.set_index("States", inplace=True)

# Plotting the heatmap
plt.figure(figsize=(16, 9))
sns.heatmap(df, annot=True, fmt=".1f", cmap="YlGnBu",
            cbar_kws={'label': '% Error'}, linewidths=0.5, linecolor='gray')

plt.title("Kharif Crop % Error for 2024-25", fontsize=18, weight='bold')
plt.xlabel("Crops", fontsize=14)
plt.ylabel("States", fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Recreate the dataset from the table
data = {
    "States": [
        "Andhra Pradesh (incl. Telangana)", "Assam", "Bihar", "Chhattisgarh", "Gujarat", "Haryana",
        "Jharkhand", "Karnataka", "Madhya Pradesh", "Maharashtra", "Orissa", "Punjab", "Rajasthan",
        "Tamilnadu", "Uttar Pradesh", "Uttarakhand", "West Bengal"
    ],
    "Rice Kharif": [2.5, 3.1, 4.9, 7.9, 9.1, 2.2, 6, 1.5, 7.7, 3.3, 7.4, 1.3, np.nan, 6.1, 3, 4, 1.4],
    "Bajra": [np.nan, np.nan, np.nan, np.nan, 6.9, 5.8, np.nan, 5.8, 4.5, 7.3, np.nan, np.nan, 15.1, np.nan, 3.1, np.nan, np.nan],
    "Jowar Kharif": [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 4.8, 7.7, 2.6, np.nan, np.nan, 8.8, 5.5, 6.8, np.nan, np.nan],
    "Maize Kharif": [6, np.nan, 11.3, 8, 10.1, np.nan, 4, 5.1, 9.8, 10.4, np.nan, 4.9, 8.4, 12.2, 5.4, np.nan, np.nan],
    "Arhar": [4.7, np.nan, np.nan, np.nan, 6.6, np.nan, 6, 8.9, 3.6, 7.1, 5.7, np.nan, np.nan, np.nan, 7.8, np.nan, np.nan],
    "Moong Kharif": [np.nan, np.nan, np.nan, np.nan, 14.7, np.nan, np.nan, 14.3, 10.4, 3.3, np.nan, np.nan, 16.5, np.nan, np.nan, np.nan, np.nan],
    "Urad Kharif": [np.nan, np.nan, np.nan, np.nan, 9.4, np.nan, np.nan, 11.4, 8, 6.4, 4, np.nan, 7.7, np.nan, 14.7, np.nan, np.nan],
    "Soybean": [np.nan, np.nan, np.nan, np.nan, 13, np.nan, np.nan, 11, 4.8, 6.2, np.nan, np.nan, 13.6, np.nan, np.nan, np.nan, np.nan],
    "GN Kharif": [6.8, np.nan, np.nan, np.nan, 16.9, np.nan, 4.7, 4.9, 5.8, 3.2, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan],
    "Castor Seed": [np.nan, np.nan, np.nan, np.nan, 1.5, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 9.1, np.nan, np.nan, np.nan, np.nan],
    "Jute": [np.nan, 4, 6, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 2],
    "Cotton": [4, np.nan, np.nan, np.nan, 10.9, 6.2, np.nan, 7.2, 5.4, 9.3, 1.8, 6.9, 12.1, 11.2, np.nan, np.nan, np.nan],
    "Sugarcane": [1.4, np.nan, 2.4, np.nan, 1.1, 1.7, np.nan, 1.8, 4.4, 4, np.nan, 2.8, np.nan, 1, 1.6, np.nan, np.nan]
}

df = pd.DataFrame(data)
df.set_index("States", inplace=True)

# Create a colormap and set NaN cells to grey
cmap = sns.color_palette("YlGnBu", as_cmap=True)
cmap.set_bad(color="grey")  # blank cells = grey

plt.figure(figsize=(16, 9))
sns.heatmap(
    df, annot=True, fmt=".1f", cmap=cmap,
    cbar_kws={'label': '% Error'},
    linewidths=0.1, linecolor='lightgrey'   # hairline grey grid lines
)

plt.title("Kharif Crop % Error for 2024-25", fontsize=18, weight='bold')
plt.xlabel("Crops", fontsize=14)
plt.ylabel("States", fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# --- your data (simplified for clarity) ---
data = {
    "States": [
        "Andhra P. (incl. TL)", "Assam", "Bihar", "Chhattisgarh", "Gujarat", "Haryana",
        "Jharkhand", "Karnataka", "Madhya Pradesh", "Maharashtra", "Orissa", "Punjab",
        "Rajasthan", "Tamilnadu", "Uttar Pradesh", "Uttarakhand", "West Bengal"
    ],
    "Rice": [0.5, 6.4, 3.7, 6.6, 3.1, -3.9, -2.4, -3.1, 2.0, -5.9, -2.7, -1.2, np.nan, -5.8, -2.2, -1.8, 2.4],
    "Bajra": [np.nan, np.nan, np.nan, np.nan, -3.0, 3.3, np.nan, 4.0, -11.5, -3.9, np.nan, np.nan, 4.7, np.nan, 3.3, np.nan, np.nan],
    "Jowar": [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, -6.1, 2.0, -3.0, np.nan, np.nan, 2.7, -24.1, 0.5, np.nan, np.nan],
    "Maize": [-1.7, np.nan, -9.2, 1.6, -0.8, np.nan, -4.2, -3.8, 1.8, -12.5, np.nan, 6.0, 5.6, 6.0, 5.3, np.nan, np.nan],
    "Arhar": [1.0, np.nan, np.nan, np.nan, 4.4, np.nan, 4.3, 10.8, -0.4, -9.5, 3.0, np.nan, np.nan, np.nan, -2.0, np.nan, np.nan],
    "Moong": [np.nan, np.nan, np.nan, np.nan, -4.6, np.nan, np.nan, -1.9, 3.2, -35.6, np.nan, np.nan, -3.0, np.nan, np.nan, np.nan, np.nan],
    "Urad": [np.nan, np.nan, np.nan, np.nan, 6.8, np.nan, 1.9, -1.0, 8.9, -31.9, 2.6, np.nan, -3.0, np.nan, 0.2, np.nan, np.nan],
    "Soybean": [np.nan, np.nan, np.nan, np.nan, 5.5, np.nan, np.nan, -6.2, 7.8, -1.6, np.nan, np.nan, 5.5, np.nan, np.nan, np.nan, np.nan],
    "GN Seed": [6.6, np.nan, np.nan, np.nan, 1.8, np.nan, np.nan, -1.3, 2.0, -6.2, np.nan, np.nan, -3.4, 2.5, 0.3, np.nan, np.nan],
    "Castor": [np.nan, np.nan, np.nan, np.nan, -1.2, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 9.7, np.nan, np.nan, np.nan, np.nan],
    "Jute": [np.nan, 4, 6, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 2],
    "Cotton": [-1.6, np.nan, np.nan, np.nan, 0.2, 3.0, np.nan, -2.6, 6.0, -8.1, 0.7, -10.5, 4.3, 0.6, np.nan, np.nan, np.nan],
    "Sugarcane": [-0.2, np.nan, -4.3, np.nan, 1.8, -5.7, np.nan, -0.3, 2.3, -0.5, np.nan, 1.1, np.nan, 2.1, -3.1, np.nan, np.nan]
}
df = pd.DataFrame(data).set_index("States")

# --- build heatmap ---
plt.figure(figsize=(14, 8))

# colormap yellow -> red
cmap = sns.color_palette("YlGnBu", as_cmap=True)
cmap.set_bad(color="lightgrey")  # grey for NaN

sns.heatmap(
    df, annot=True, fmt=".1f", cmap=cmap,
    cbar_kws={'label': 'RMSE (%)'},
    linewidths=0.5, linecolor='white'   # thin white grid lines
)

# Titles
plt.title("Kharif Crop % Error for 2024-25", fontsize=12, weight='bold')

# Labels
plt.xlabel("Crops")
plt.ylabel("States")
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# --- your data (simplified for clarity) ---
data = {
    "States": [
        "Andhra P. (incl. TL)", "Assam", "Bihar", "Chhattisgarh", "Gujarat", "Haryana",
        "Jharkhand", "Karnataka", "Madhya Pradesh", "Maharashtra", "Orissa", "Punjab",
        "Rajasthan", "Tamilnadu", "Uttar Pradesh", "Uttarakhand", "West Bengal"
    ],
    "Rice": [0.5, 6.4, 3.7, 6.6, 3.1, -3.9, -2.4, -3.1, 2.0, -5.9, -2.7, -1.2, np.nan, -5.8, -2.2, -1.8, 2.4],
    "Bajra": [np.nan, np.nan, np.nan, np.nan, -3.0, 3.3, np.nan, 4.0, -11.5, -3.9, np.nan, np.nan, 4.7, np.nan, 3.3, np.nan, np.nan],
    "Jowar": [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, -6.1, 2.0, -3.0, np.nan, np.nan, 2.7, -24.1, 0.5, np.nan, np.nan],
    "Maize": [-1.7, np.nan, -9.2, 1.6, -0.8, np.nan, -4.2, -3.8, 1.8, -12.5, np.nan, 6.0, 5.6, 6.0, 5.3, np.nan, np.nan],
    "Arhar": [1.0, np.nan, np.nan, np.nan, 4.4, np.nan, 4.3, 10.8, -0.4, -9.5, 3.0, np.nan, np.nan, np.nan, -2.0, np.nan, np.nan],
    "Moong": [np.nan, np.nan, np.nan, np.nan, -4.6, np.nan, np.nan, -1.9, 3.2, -35.6, np.nan, np.nan, -3.0, np.nan, np.nan, np.nan, np.nan],
    "Urad": [np.nan, np.nan, np.nan, np.nan, 6.8, np.nan, 1.9, -1.0, 8.9, -31.9, 2.6, np.nan, -3.0, np.nan, 0.2, np.nan, np.nan],
    "Soybean": [np.nan, np.nan, np.nan, np.nan, 5.5, np.nan, np.nan, -6.2, 7.8, -1.6, np.nan, np.nan, 5.5, np.nan, np.nan, np.nan, np.nan],
    "GN Seed": [6.6, np.nan, np.nan, np.nan, 1.8, np.nan, np.nan, -1.3, 2.0, -6.2, np.nan, np.nan, -3.4, 2.5, 0.3, np.nan, np.nan],
    "Castor": [np.nan, np.nan, np.nan, np.nan, -1.2, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 9.7, np.nan, np.nan, np.nan, np.nan],
    "Jute": [np.nan, 4, 6, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 2],
    "Cotton": [-1.6, np.nan, np.nan, np.nan, 0.2, 3.0, np.nan, -2.6, 6.0, -8.1, 0.7, -10.5, 4.3, 0.6, np.nan, np.nan, np.nan],
    "Sugarcane": [-0.2, np.nan, -4.3, np.nan, 1.8, -5.7, np.nan, -0.3, 2.3, -0.5, np.nan, 1.1, np.nan, 2.1, -3.1, np.nan, np.nan]
}
df = pd.DataFrame(data).set_index("States")

# --- build heatmap ---
plt.figure(figsize=(15, 9))

# Beautiful diverging colormap (negative = red, positive = blue)
cmap = sns.diverging_palette(220, 20, as_cmap=True)
cmap.set_bad(color="lightgrey")  # grey for NaN

sns.heatmap(
    df, annot=True, fmt=".1f", cmap=cmap,
    center=0,  # center colormap at zero
    cbar_kws={'label': 'Difference (%)'},
    linewidths=0.4, linecolor='white',
    annot_kws={"size": 7, "weight": "light", "color": "black"}
)

# Titles
plt.title("Validation for 2024-25 (IEG vs 3AE-MoA&FW): % Difference", fontsize=16, weight='bold', pad=20)

# Labels
plt.xlabel("Crops", fontsize=12, weight='bold')
plt.ylabel("States", fontsize=12, weight='bold')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(rotation=0, fontsize=10)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# --- your data ---
data = {
    "States": [
        "Andhra P. (incl. TL)", "Assam", "Bihar", "Chhattisgarh", "Gujarat", "Haryana",
        "Jharkhand", "Karnataka", "Madhya Pradesh", "Maharashtra", "Orissa", "Punjab",
        "Rajasthan", "Tamilnadu", "Uttar Pradesh", "Uttarakhand", "West Bengal"
    ],
    "Rice": [0.5, 6.4, 3.7, 6.6, 3.1, -3.9, -2.4, -3.1, 2.0, -5.9, -2.7, -1.2, np.nan, -5.8, -2.2, -1.8, 2.4],
    "Bajra": [np.nan, np.nan, np.nan, np.nan, -3.0, 3.3, np.nan, 4.0, -11.5, -3.9, np.nan, np.nan, 4.7, np.nan, 3.3, np.nan, np.nan],
    "Jowar": [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, -6.1, 2.0, -3.0, np.nan, np.nan, 2.7, -24.1, 0.5, np.nan, np.nan],
    "Maize": [-1.7, np.nan, -9.2, 1.6, -0.8, np.nan, -4.2, -3.8, 1.8, -12.5, np.nan, 6.0, 5.6, 6.0, 5.3, np.nan, np.nan],
    "Arhar": [1.0, np.nan, np.nan, np.nan, 4.4, np.nan, 4.3, 10.8, -0.4, -9.5, 3.0, np.nan, np.nan, np.nan, -2.0, np.nan, np.nan],
    "Moong": [np.nan, np.nan, np.nan, np.nan, -4.6, np.nan, np.nan, -1.9, 3.2, -35.6, np.nan, np.nan, -3.0, np.nan, np.nan, np.nan, np.nan],
    "Urad": [np.nan, np.nan, np.nan, np.nan, 6.8, np.nan, 1.9, -1.0, 8.9, -31.9, 2.6, np.nan, -3.0, np.nan, 0.2, np.nan, np.nan],
    "Soybean": [np.nan, np.nan, np.nan, np.nan, 5.5, np.nan, np.nan, -6.2, 7.8, -1.6, np.nan, np.nan, 5.5, np.nan, np.nan, np.nan, np.nan],
    "GN Seed": [6.6, np.nan, np.nan, np.nan, 1.8, np.nan, np.nan, -1.3, 2.0, -6.2, np.nan, np.nan, -3.4, 2.5, 0.3, np.nan, np.nan],
    "Castor": [np.nan, np.nan, np.nan, np.nan, -1.2, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 9.7, np.nan, np.nan, np.nan, np.nan],
    "Jute": [np.nan, 4, 6, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 2],
    "Cotton": [-1.6, np.nan, np.nan, np.nan, 0.2, 3.0, np.nan, -2.6, 6.0, -8.1, 0.7, -10.5, 4.3, 0.6, np.nan, np.nan, np.nan],
    "Sugarcane": [-0.2, np.nan, -4.3, np.nan, 1.8, -5.7, np.nan, -0.3, 2.3, -0.5, np.nan, 1.1, np.nan, 2.1, -3.1, np.nan, np.nan]
}
df = pd.DataFrame(data).set_index("States")

# --- build heatmap ---
plt.figure(figsize=(15, 9))

# Bold diverging colormap (red vs blue, high contrast)
cmap = plt.cm.get_cmap("seismic").copy()
cmap.set_bad(color="lightgrey")  # grey for NaN

sns.heatmap(
    df, annot=True, fmt=".1f", cmap=cmap,
    center=0,  # center colormap at zero
    cbar_kws={'label': 'Difference (%)'},
    linewidths=0.6, linecolor='white',
    annot_kws={"size": 8, "weight": "light", "color": "black"}
)

# Titles
plt.title("Validation for 2024-25 (IEG vs 3AE-MoA&FW): % Difference",
          fontsize=16, weight='bold', pad=20)

# Labels
plt.xlabel("Crops", fontsize=12, weight='bold')
plt.ylabel("States", fontsize=12, weight='bold')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(rotation=0, fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3080505392.py:33: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("seismic").copy()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# --- your data ---
data = {
    "States": [
        "Andhra P. (incl. TL)", "Assam", "Bihar", "Chhattisgarh", "Gujarat", "Haryana",
        "Jharkhand", "Karnataka", "Madhya Pradesh", "Maharashtra", "Orissa", "Punjab",
        "Rajasthan", "Tamilnadu", "Uttar Pradesh", "Uttarakhand", "West Bengal"
    ],
    "Rice": [0.5, 6.4, 3.7, 6.6, 3.1, -3.9, -2.4, -3.1, 2.0, -5.9, -2.7, -1.2, np.nan, -5.8, -2.2, -1.8, 2.4],
    "Bajra": [np.nan, np.nan, np.nan, np.nan, -3.0, 3.3, np.nan, 4.0, -11.5, -3.9, np.nan, np.nan, 4.7, np.nan, 3.3, np.nan, np.nan],
    "Jowar": [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, -6.1, 2.0, -3.0, np.nan, np.nan, 2.7, -24.1, 0.5, np.nan, np.nan],
    "Maize": [-1.7, np.nan, -9.2, 1.6, -0.8, np.nan, -4.2, -3.8, 1.8, -12.5, np.nan, 6.0, 5.6, 6.0, 5.3, np.nan, np.nan],
    "Arhar": [1.0, np.nan, np.nan, np.nan, 4.4, np.nan, 4.3, 10.8, -0.4, -9.5, 3.0, np.nan, np.nan, np.nan, -2.0, np.nan, np.nan],
    "Moong": [np.nan, np.nan, np.nan, np.nan, -4.6, np.nan, np.nan, -1.9, 3.2, -35.6, np.nan, np.nan, -3.0, np.nan, np.nan, np.nan, np.nan],
    "Urad": [np.nan, np.nan, np.nan, np.nan, 6.8, np.nan, 1.9, -1.0, 8.9, -31.9, 2.6, np.nan, -3.0, np.nan, 0.2, np.nan, np.nan],
    "Soybean": [np.nan, np.nan, np.nan, np.nan, 5.5, np.nan, np.nan, -6.2, 7.8, -1.6, np.nan, np.nan, 5.5, np.nan, np.nan, np.nan, np.nan],
    "GN Seed": [6.6, np.nan, np.nan, np.nan, 1.8, np.nan, np.nan, -1.3, 2.0, -6.2, np.nan, np.nan, -3.4, 2.5, 0.3, np.nan, np.nan],
    "Castor": [np.nan, np.nan, np.nan, np.nan, -1.2, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 9.7, np.nan, np.nan, np.nan, np.nan],
    "Jute": [np.nan, 4, 6, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 2],
    "Cotton": [-1.6, np.nan, np.nan, np.nan, 0.2, 3.0, np.nan, -2.6, 6.0, -8.1, 0.7, -10.5, 4.3, 0.6, np.nan, np.nan, np.nan],
    "Sugarcane": [-0.2, np.nan, -4.3, np.nan, 1.8, -5.7, np.nan, -0.3, 2.3, -0.5, np.nan, 1.1, np.nan, 2.1, -3.1, np.nan, np.nan]
}
df = pd.DataFrame(data).set_index("States")

# --- build heatmap ---
plt.figure(figsize=(15, 9))

# Bold diverging colormap (blue ↔ white ↔ red)
cmap = plt.cm.get_cmap("RdBu_r").copy()
cmap.set_bad(color="lightgrey")  # grey for NaN

sns.heatmap(
    df, annot=True, fmt=".1f", cmap=cmap,
    center=0, vmin=-40, vmax=15,  # fix range for stronger contrast
    cbar_kws={'label': 'Difference (%)'},
    linewidths=0.6, linecolor='white',
    annot_kws={"size": 8, "weight": "light", "color": "black"}
)

# Titles
plt.title("Validation for 2024-25 (IEG vs MoA&FW): Difference (%)",
          fontsize=16, weight='bold', pad=20)

# Labels
plt.xlabel("Crops", fontsize=12, weight='bold')
plt.ylabel("States", fontsize=12, weight='bold')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(rotation=0, fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3268804512.py:33: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("RdBu_r").copy()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# --- your data ---
data = {
    "States": [
        "Andhra P. (incl. TL)", "Assam", "Bihar", "Chhattisgarh", "Gujarat", "Haryana",
        "Jharkhand", "Karnataka", "Madhya Pradesh", "Maharashtra", "Orissa", "Punjab",
        "Rajasthan", "Tamilnadu", "Uttar Pradesh", "Uttarakhand", "West Bengal"
    ],
    "Rice": [0.5, 6.4, 3.7, 6.6, 3.1, -3.9, -2.4, -3.1, 2.0, -5.9, -2.7, -1.2, np.nan, -5.8, -2.2, -1.8, 2.4],
    "Bajra": [np.nan, np.nan, np.nan, np.nan, -3.0, 3.3, np.nan, 4.0, -11.5, -3.9, np.nan, np.nan, 4.7, np.nan, 3.3, np.nan, np.nan],
    "Jowar": [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, -6.1, 2.0, -3.0, np.nan, np.nan, 2.7, -24.1, 0.5, np.nan, np.nan],
    "Maize": [-1.7, np.nan, -9.2, 1.6, -0.8, np.nan, -4.2, -3.8, 1.8, -12.5, np.nan, 6.0, 5.6, 6.0, 5.3, np.nan, np.nan],
    "Arhar": [1.0, np.nan, np.nan, np.nan, 4.4, np.nan, 4.3, 10.8, -0.4, -9.5, 3.0, np.nan, np.nan, np.nan, -2.0, np.nan, np.nan],
    "Moong": [np.nan, np.nan, np.nan, np.nan, -4.6, np.nan, np.nan, -1.9, 3.2, -35.6, np.nan, np.nan, -3.0, np.nan, np.nan, np.nan, np.nan],
    "Urad": [np.nan, np.nan, np.nan, np.nan, 6.8, np.nan, 1.9, -1.0, 8.9, -31.9, 2.6, np.nan, -3.0, np.nan, 0.2, np.nan, np.nan],
    "Soybean": [np.nan, np.nan, np.nan, np.nan, 5.5, np.nan, np.nan, -6.2, 7.8, -1.6, np.nan, np.nan, 5.5, np.nan, np.nan, np.nan, np.nan],
    "GN Seed": [6.6, np.nan, np.nan, np.nan, 1.8, np.nan, np.nan, -1.3, 2.0, -6.2, np.nan, np.nan, -3.4, 2.5, 0.3, np.nan, np.nan],
    "Castor": [np.nan, np.nan, np.nan, np.nan, -1.2, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 9.7, np.nan, np.nan, np.nan, np.nan],
    "Jute": [np.nan, 4, 6, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 2],
    "Cotton": [-1.6, np.nan, np.nan, np.nan, 0.2, 3.0, np.nan, -2.6, 6.0, -8.1, 0.7, -10.5, 4.3, 0.6, np.nan, np.nan, np.nan],
    "Sugarcane": [-0.2, np.nan, -4.3, np.nan, 1.8, -5.7, np.nan, -0.3, 2.3, -0.5, np.nan, 1.1, np.nan, 2.1, -3.1, np.nan, np.nan]
}
df = pd.DataFrame(data).set_index("States")

# --- build heatmap ---
plt.figure(figsize=(14, 8))

# colormap yellow -> red
cmap = sns.color_palette("BuGn_r", as_cmap=True)
cmap.set_bad(color="lightgrey")  # grey for NaN

sns.heatmap(
    df, annot=True, fmt=".1f", cmap=cmap,
    cbar_kws={'label': 'RMSE (%)'},
    linewidths=0.5, linecolor='white'   # thin white grid lines
)

# Titles
plt.title("Validation for 2024-25 (IEG vs MoA&FW): Difference (%)",
          fontsize=12, weight='bold', pad=20)

# Labels
plt.xlabel("Crops")
plt.ylabel("States")
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# --- your data ---
data = {
    "States": [
        "Andhra P. (incl. TL)", "Assam", "Bihar", "Chhattisgarh", "Gujarat", "Haryana",
        "Jharkhand", "Karnataka", "Madhya Pradesh", "Maharashtra", "Orissa", "Punjab",
        "Rajasthan", "Tamilnadu", "Uttar Pradesh", "Uttarakhand", "West Bengal"
    ],
   "Rice" : [0.7, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 4.2, np.nan, np.nan, np.nan, np.nan, np.nan, 6.9, np.nan, np.nan, np.nan],
   "Wheat" : [np.nan, np.nan, 5.5, np.nan, 2.2, 2.1, np.nan, np.nan, 9.2, 4.9, np.nan, 2.2, 2, np.nan, 2.7, np.nan, np.nan],
   "Jowar" : [9.1, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 8, np.nan, 9.8, np.nan, np.nan, np.nan, 9.4, np.nan, np.nan, np.nan],
   "Maize" : [3.6, np.nan, 9.5, np.nan, 2.3, np.nan, np.nan, 4.5, np.nan, 6.1, np.nan, np.nan, np.nan, 8.4, 5.7, np.nan, 6.2],
   "Barley" : [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 5.6, np.nan, np.nan, np.nan, 5.4, np.nan, 3.5, 6.4, np.nan],
   "Masur" : [np.nan, np.nan, 10.4, np.nan, np.nan, np.nan, 5.5, np.nan, 8.5, np.nan, np.nan, np.nan, np.nan, np.nan, 6.2, np.nan, 3.1],
   "Gram" : [7, np.nan, np.nan, 11.5, 6.9, np.nan, np.nan, 7.5, 7.5, 5.7, np.nan, np.nan, 7.6, np.nan, 8.9, np.nan, np.nan],
   "Moong" : [14.8, np.nan, np.nan, np.nan, 18.1, np.nan, np.nan, 7.7, np.nan, np.nan, np.nan, np.nan, np.nan, 9, np.nan, np.nan, 5.6],
   "Urad" : [11.7, 3.3, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 9.1, np.nan, np.nan, np.nan],
   "Rapeseed Mustard" : [np.nan, 4.8, np.nan, np.nan, 3, 6.1, 3.2, np.nan, 2.8, np.nan, np.nan, np.nan, 4.3, np.nan, 4.8, np.nan, 4.8],
   "Groundnut" : [4.2, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 8, np.nan, np.nan, np.nan, np.nan, np.nan, 7.1, np.nan, np.nan, 4.4],
   "Potato" : [np.nan, 10.5, 7.9, np.nan, 3.5, np.nan, np.nan, np.nan, 8.3, np.nan, np.nan, 5, np.nan, np.nan, 3.2, np.nan, 7.3],

}
df = pd.DataFrame(data).set_index("States")

# --- build heatmap ---
plt.figure(figsize=(14, 8))

# colormap yellow -> red
cmap = sns.color_palette("BuGn", as_cmap=True)
cmap.set_bad(color="lightgrey")  # grey for NaN

sns.heatmap(
    df, annot=True, fmt=".1f", cmap=cmap,
    cbar_kws={'label': 'RMSE (%)'},
    linewidths=0.5, linecolor='white'   # thin white grid lines
)

# Titles
plt.title("RMSE (%) of Estimates for the Rabi Crop Yield Model (2000–01 to 2023–24)",
          fontsize=14, weight='bold', pad=20)

# Labels
plt.xlabel("Rabi Crops", fontsize=14, weight='bold')
plt.ylabel("States", fontsize=14, weight='bold')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# --- your data ---
data = {
    "States": [
        "Andhra P. (incl. TL)", "Assam", "Bihar", "Chhattisgarh", "Gujarat", "Haryana",
        "Jharkhand", "Karnataka", "Madhya Pradesh", "Maharashtra", "Orissa", "Punjab",
        "Rajasthan", "Tamilnadu", "Uttar Pradesh", "Uttarakhand", "West Bengal"
    ],
   "Rice" : [0.5, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 1.3, np.nan, np.nan, np.nan, np.nan, np.nan, 6.6, np.nan, np.nan, np.nan],
   "Wheat" : [np.nan, np.nan, 2.5, np.nan, -3.6, -0.5, np.nan, np.nan, 2.4, 5.7, np.nan, -1.4, 0.0, np.nan, 0.8, np.nan, np.nan],
   "Jowar" : [1.7, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0.2, np.nan, 5.3, np.nan, np.nan, np.nan, -15.3, np.nan, np.nan, np.nan],
   "Maize" : [3.9, np.nan, -3.2, np.nan, 2.8, np.nan, np.nan, 4, np.nan, -1.7, np.nan, np.nan, np.nan, -3.5, 3.1, np.nan, 0.9],
   "Barley" : [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, -2.7, np.nan, np.nan, np.nan, 0.5, np.nan, 4.3, -7.1, np.nan],
    "Masur" : [np.nan, np.nan, -8.4, np.nan, np.nan, np.nan, -1.7, np.nan, 6.6, np.nan, np.nan, np.nan, np.nan, np.nan, -4.3, np.nan, -3.5],
   "Gram" : [0.0, np.nan, np.nan, 8.4, -2.4, np.nan, np.nan, 4.4, -4.6, 3.1, np.nan, np.nan, 0.1, np.nan, -2.4, np.nan, np.nan],
      "Moong" : [1.4, np.nan, np.nan, np.nan, 0.4, np.nan, np.nan, 4.7, np.nan, np.nan, np.nan, np.nan, np.nan, -1.2, np.nan, np.nan, 2.9],
   "Urad" : [-1.7, 1.5, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 5.9, np.nan, np.nan, np.nan],
   "Rapeseed Mustard" : [np.nan, -1.8, np.nan, np.nan, 2.7, -1.4, -3.4, np.nan, 10.1, np.nan, np.nan, np.nan, 2.9, np.nan, 2.8, np.nan, -2.1],
   "Groundnut" : [3.9, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 8.3, np.nan, np.nan, np.nan, np.nan, np.nan, -0.6, np.nan, np.nan, -0.6],
   "Potato" : [np.nan, -0.9, 1.8, np.nan, 4.8, np.nan, np.nan, np.nan, 4.4, np.nan, np.nan, 1.2, np.nan, np.nan, 0.6, np.nan, 3.8],

}
df = pd.DataFrame(data).set_index("States")

# --- build heatmap ---
plt.figure(figsize=(14, 8))

# colormap yellow -> red
cmap = sns.color_palette("OrRd_r", as_cmap=True)
cmap.set_bad(color="lightgrey")  # grey for NaN

sns.heatmap(
    df, annot=True, fmt=".1f", cmap=cmap,
    cbar_kws={'label': 'Difference (%)'},
    linewidths=0.5, linecolor='white'   # thin white grid lines
)

# Titles
plt.title("Validation of Rabi Crop Yield Forecasts for 2024-25 (IEG vs MoA&FW): Difference (%)",
          fontsize=14, weight='bold', pad=20)

# Labels
plt.xlabel("Rabi Crops", fontsize=14, weight='bold')
plt.ylabel("States", fontsize=14, weight='bold')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()
